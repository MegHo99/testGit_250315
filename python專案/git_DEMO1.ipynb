# %% [markdown]
# <a href="https://colab.research.google.com/github/MegHo99/testGit_250315/blob/main/python%E5%B0%88%E6%A1%88/git_DEMO1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 課堂測試

# %% [markdown]
# - 標題1

# %%
import cmath

a = float(input('輸入 a: '))
b = float(input('輸入 b: '))
c = float(input('輸入 c: '))

# 計算判別式
d = (b**2) - 4*(a*c)

# 根據判別式的值找出根
if d > 0:
    sol1 = (-b - cmath.sqrt(d))/(2*a)
    sol2 = (-b + cmath.sqrt(d))/(2*a)
    print('這個方程式有兩個不同的實數根： {} 和 {}'.format(sol1,sol2))
elif d == 0:
    sol1 = (-b - cmath.sqrt(d))/(2*a)
    print('這個方程式有一個重複的實數根： {}'.format(sol1))
else:
    sol1 = (-b - cmath.sqrt(d))/(2*a)
    sol2 = (-b + cmath.sqrt(d))/(2*a)
    print('這個方程式有兩個複數根： {} 和 {}'.format(sol1,sol2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 import cmath
# ----> 3 a = float(input('輸入 a: '))
#       4 b = float(input('輸入 b: '))
#       5 c = float(input('輸入 c: '))
#
# ValueError: could not convert string to float: ''

# %%
import numpy as np
import matplotlib.pyplot as plt

# 設定 x 軸的範圍和間隔
x = np.linspace(0, 2*np.pi, 100)

# 計算 y 值 (sin(x))
y = np.sin(x)

# 畫出正弦波
plt.plot(x, y)

# 設定圖表標題和軸標籤
plt.title('Sin plot11')
plt.xlabel('x')
plt.ylabel('sin(x)')

# 顯示圖表
plt.show()

# %% [markdown]
# - 同時顯示cos, sin圖形

# %% [markdown]
# ### cos plot

# %%
import numpy as np
import matplotlib.pyplot as plt

# 設定 x 軸的範圍和間隔
x = np.linspace(0, 2*np.pi, 100)

# 計算 y 值 (cos(x))
y = np.cos(x)

# 畫出餘弦波
plt.plot(x, y)

# 設定圖表標題和軸標籤
plt.title('Cosine plot')
plt.xlabel('x')
plt.ylabel('cos(x)')

# 顯示圖表
plt.show()

# %% [markdown]
# ### 產生cos與sin波圖形

# %%
import numpy as np
import matplotlib.pyplot as plt

# 產生數據
x = np.linspace(0, 2 * np.pi, 100)
cos_y = np.cos(x)
sin_y = np.sin(x)

# 繪製cos波圖形
plt.figure(figsize=(10, 5))
plt.plot(x, cos_y, label='cos(x)')
plt.title('Cosine Wave')
plt.xlabel('x')
plt.ylabel('cos(x)')
plt.legend()
plt.grid(True)
plt.show()

# 繪製sin波圖形
plt.figure(figsize=(10, 5))
plt.plot(x, sin_y, label='sin(x)', color='orange')
plt.title('Sine Wave')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()
plt.grid(True)
plt.show()
